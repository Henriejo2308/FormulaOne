# %%
import numpy as np
import pandas as pd
# Import Data
results_dataframe = pd.read_csv("archive-3/results.csv")
circuits_dataframe = pd.read_csv("archive-3/circuits.csv")
drivers_dataframe = pd.read_csv("archive-3/drivers.csv")
races_dataframe = pd.read_csv("archive-3/races.csv")
constructor_dataframe = pd.read_csv("archive-3/constructors.csv")
lap_times_dataframe = pd.read_csv("archive-3/lap_times.csv")

# %%
# Prints Results Data Frame
results_dataframe.head()# Prints Drivers Data Frame
drivers_dataframe.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
# Join Data Frames
driver_result_dataframe = pd.merge(results_dataframe,drivers_dataframe,on="driverId")
race_result_dataframe = pd.merge(driver_result_dataframe,races_dataframe,on="raceId")
complete_race_data_dataframe = pd.merge(race_result_dataframe,constructor_dataframe,on="constructorId")

complete_race_data_dataframe.head()
# Out:
#    resultId  raceId  driverId  constructorId number_x  grid position  \
# 0         1      18         1              1       22     1        1
# 1         5      18         5              1       23     3        5
# 2        27      19         1              1       22     9        5
# 3        25      19         5              1       23     8        3
# 4        57      20         1              1       22     3       13
#
#   positionText  positionOrder  points  ...  fp3_date fp3_time quali_date  \
# 0            1              1    10.0  ...        \N       \N         \N
# 1            5              5     4.0  ...        \N       \N         \N
# 2            5              5     4.0  ...        \N       \N         \N
# 3            3              3     6.0  ...        \N       \N         \N
# 4           13             13     0.0  ...        \N       \N         \N
#
#   quali_time sprint_date sprint_time constructorRef   name_y nationality_y  \
# 0         \N          \N          \N        mclaren  McLaren       British
# 1         \N          \N          \N        mclaren  McLaren       British
# 2         \N          \N          \N        mclaren  McLaren       British
# 3         \N          \N          \N        mclaren  McLaren       British
# 4         \N          \N          \N        mclaren  McLaren       British
#
#                                     url
# 0  http://en.wikipedia.org/wiki/McLaren
# 1  http://en.wikipedia.org/wiki/McLaren
# 2  http://en.wikipedia.org/wiki/McLaren
# 3  http://en.wikipedia.org/wiki/McLaren
# 4  http://en.wikipedia.org/wiki/McLaren
#
# [5 rows x 47 columns]

# %%
complete_race_data_dataframe = complete_race_data_dataframe.drop (columns=["url_x","url_y","name_y","nationality_y","url","time_y"])
complete_race_data_dataframe.head()
# Out:
#    resultId  raceId  driverId  constructorId number_x  grid position  \
# 0         1      18         1              1       22     1        1
# 1         5      18         5              1       23     3        5
# 2        27      19         1              1       22     9        5
# 3        25      19         5              1       23     8        3
# 4        57      20         1              1       22     3       13
#
#   positionText  positionOrder  points  ...  fp1_time fp2_date fp2_time  \
# 0            1              1    10.0  ...        \N       \N       \N
# 1            5              5     4.0  ...        \N       \N       \N
# 2            5              5     4.0  ...        \N       \N       \N
# 3            3              3     6.0  ...        \N       \N       \N
# 4           13             13     0.0  ...        \N       \N       \N
#
#   fp3_date fp3_time quali_date quali_time  sprint_date sprint_time  \
# 0       \N       \N         \N         \N           \N          \N
# 1       \N       \N         \N         \N           \N          \N
# 2       \N       \N         \N         \N           \N          \N
# 3       \N       \N         \N         \N           \N          \N
# 4       \N       \N         \N         \N           \N          \N
#
#   constructorRef
# 0        mclaren
# 1        mclaren
# 2        mclaren
# 3        mclaren
# 4        mclaren
#
# [5 rows x 41 columns]

# %%
# Filter & Calculate Results
total_wins = complete_race_data_dataframe[(complete_race_data_dataframe["position"]== "1")] 
total_wins["position_mod"] = total_wins["position"].astype(int)
total_wins = total_wins.groupby(["driverRef","nationality_x"])["position_mod"].sum().reset_index()
total_wins = total_wins.sort_values(by=["position_mod"], ascending=False)
total_wins = total_wins.head(10)
# Out:
# /var/folders/n9/rt0b9w817c3ctp24777l4pbr0000gn/T/ipykernel_20409/3169254076.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_wins["position_mod"] = total_wins["position"].astype(int)

# %%
import pandas as pd

# Les inn data fra filer
lap_times_dataframe = pd.read_csv('archive-3/lap_times.csv')
drivers_dataframe = pd.read_csv('archive-3/drivers.csv')
# Les inn data fra drivers.csv-filen
drivers_dataframe = pd.read_csv('archive-3/drivers.csv')

# Referer til driverID-kolonnen
driver_ids = drivers_dataframe['driverID']

# Du kan nå bruke driver_ids som en Series for å få tilgang til driverID-verdiene.

# Vis de første 6 radene av den sammenkoblede tabellen
driver_ids.head(6)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'driverID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/ridwana/Documents/FormulaOne/formula1.ipynb Cell 6 line 1
#       <a href='vscode-notebook-cell:/Users/ridwana/Documents/FormulaOne/formula1.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a> drivers_dataframe = pd.read_csv('archive-3/drivers.csv')
#       <a href='vscode-notebook-cell:/Users/ridwana/Documents/FormulaOne/formula1.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> # Referer til driverID-kolonnen
# ---> <a href='vscode-notebook-cell:/Users/ridwana/Documents/FormulaOne/formula1.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a> driver_ids = drivers_dataframe['driverID']
#      <a href='vscode-notebook-cell:/Users/ridwana/Documents/FormulaOne/formula1.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a> # Du kan nå bruke driver_ids som en Series for å få tilgang til driverID-verdiene.
#      <a href='vscode-notebook-cell:/Users/ridwana/Documents/FormulaOne/formula1.ipynb#X10sZmlsZQ%3D%3D?line=12'>13</a>
#      <a href='vscode-notebook-cell:/Users/ridwana/Documents/FormulaOne/formula1.ipynb#X10sZmlsZQ%3D%3D?line=13'>14</a> # Vis de første 6 radene av den sammenkoblede tabellen
#      <a href='vscode-notebook-cell:/Users/ridwana/Documents/FormulaOne/formula1.ipynb#X10sZmlsZQ%3D%3D?line=14'>15</a> driver_ids.head(6)
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'driverID'
